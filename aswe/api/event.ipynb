# %% [markdown]
# ## Event

# %% [markdown]
# ### Imports

# %%
from aswe.api.event.event import EventApi
from aswe.utils.request import http_request

api = EventApi()

# %% [markdown]
# ### Examples

# %%
url = api.events()
url = f"{url}&postlCode=70173&locale=de&radius=50"
print(url)
# Out:
# https://app.ticketmaster.com/discovery/v2//events?apikey=neJAdTtlbleapdGjrcAnIjW92Fh8DAGa&postlCode=70173&locale=de&radius=50

# %%
response = http_request(url)
# Out:
# 2022-10-26 18:03:31.786 | SUCCESS  | src.utils.http_request:http_request:32 - Successfully fetched data from https://app.ticketmaster.com/discovery/v2//events?apikey=neJAdTtlbleapdGjrcAnIjW92Fh8DAGa&postlCode=70173&locale=de&radius=50

# %%
response.json()
# Out:
# {'_embedded': {'events': [{'name': 'Harry Potter and the Cursed Child - Parts 1 & 2 Wed 14:00 & 19:00',
#     'type': 'event',
#     'id': 'G5djZ97WU8YE2',
#     'test': False,
#     'url': 'https://theatre.ticketmaster.co.uk/book/17YYA-harry-potter-and-the-cursed-child/#perf=17YYA-362&date=2022-10-26&time=2.00PM',
#     'locale': 'de-de',
#     'images': [{'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/5f2/811a0e95-2929-478d-bc36-8784864195f2_1469761_EVENT_DETAIL_PAGE_16_9.jpg',
#       'width': 205,
#       'height': 115,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/5f2/811a0e95-2929-478d-bc36-8784864195f2_1469761_RECOMENDATION_16_9.jpg',
#       'width': 100,
#       'height': 56,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/5f2/811a0e95-2929-478d-bc36-8784864195f2_1469761_ARTIST_PAGE_3_2.jpg',
#       'width': 305,
#       'height': 203,
# ...
